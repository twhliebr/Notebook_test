# %% [markdown]
# # Data analysis prop 64
# ## my first-notebook, a small test
# And another line of text

# %% [markdown]
# ### Loading packages

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print np
print pd
print plt
# Out:
# <module 'numpy' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\site-packages\numpy\__init__.pyc'>
# <module 'pandas' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\site-packages\pandas\__init__.pyc'>
# <module 'matplotlib.pyplot' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\site-packages\matplotlib\pyplot.pyc'>

# %% [markdown]
# ## Reading in the data

# %%
props=pd.read_csv('committees.csv')
contribs=pd.read_csv('contributions.csv')

# %% [markdown]
# ### Inspecting the data :

# %%
props.head(3)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
# 2                384                 1282321
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs.head(3)
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# 1                 MYRNA        SAN DIEGO                CA           92109
# 2                   LEO        ESCONDIDO                CA           92025
#
#        contributor_employer contributor_occupation  \
# 0                A NEW PATH     EXECUTIVE DIRECTOR
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name.value_counts().reset_index()
#propvals = props.prop_name.value_counts().reset_index()
##
#propvalsdf = pd.DataFrame(propvals)
#propvalsdf.reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts().head()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# Name: prop_name, dtype: int64

# %%
#props.where(props['prop_name']=='PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.').dropna()
prop = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
merged = pd.merge(prop, contribs, on='calaccess_committee_id')
merged.head(3)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# 1                456                 1381808
# 2                456                 1381808
#
#                                     committee_name_x committee_position  \
# 0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...            SUPPORT
# 1  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...            SUPPORT
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
merged['amount'].sum()
# Out:
# 35177017.640000001

# %%
merged['committee_position'].value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
#support  = merged[merged.committee_position=='SUPPORT']
#support.amount.sum()
#support
support = merged.where(merged['committee_position']=='SUPPORT').dropna(subset=['committee_position'])
support['amount'].sum()
# Out:
# 32675806.0

# %%
support.head(3)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
#
#    ccdc_prop_id                                          prop_name  \
# 0          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0              456.0               1381808.0
# 1              456.0               1381808.0
# 2              456.0               1381808.0
#
#                                     committee_name_x committee_position  \
# 0  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...            SUPPORT
# 1  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...            SUPPORT
# ...

# %%
#oppose = merged[merged.committee_position=='OPPOSE']
#oppose
oppose = merged.where(merged['committee_position'] == 'OPPOSE').dropna(subset=['committee_position'])
oppose['amount'].sum()
# Out:
# 2501211.6400000001

# %%
print 'percentage is:'
support['amount'].sum()/merged['amount'].sum()
# Out:
# percentage is:
# 0.92889642704798669

# %%
print 'Max amount obtained by support and oppose:'
print support['amount'].max()
print oppose['amount'].max()
print 'Min amount obtained by support and oppose:'
print support['amount'].min()
print oppose['amount'].min()
# Out:
# Max amount obtained by support and oppose:
# 4000000.0
# 1000000.0
# Min amount obtained by support and oppose:
# -150000.0
# 50.0

# %%
print 'here is a boxplot:'
plt.figure(figsize=(3, 4))
ax1 = plt.subplot(1,1,1)
ax1.boxplot([support['amount'], oppose['amount']])
ax1.set_title('Support and Oppose boxplots', alpha=1, size=10)
ax1.set_ylabel('Dollars in millions', alpha = 0.8)
ax1.set_xlabel('Group', alpha=0.8)
plt.setp(ax1,yticks=[0,1000000,2000000,3000000,4000000], yticklabels=[0, 1,2,3,4])
plt.setp(ax1, xticks=[1,2], xticklabels=['support','oppose'],)
plt.tight_layout()
#plt.savefig('boxplots.pdf')
#plt.savefig('boxplots.png')
#plt.savefig('boxplots2.pdf', bbox_inches='tight')
# Out:
# here is a boxplot:
# <img src="data:image/png;base64,..." width="300">

# %%
top5sup=merged.sort_values(by='amount', ascending=False).head(5)
top5sup
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 142  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 846  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 851  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 852  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 142            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 79             83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 846            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 851            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 852            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 142                456                 1381808
# ...

# %%
top5op = oppose.sort_values(by='amount', ascending=False).head(5)
top5op
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
# 840  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e          1381868.0
#
#      ccdc_prop_id                                          prop_name  \
# 839          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 308          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 840          83.0  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 839              463.0               1387789.0
# ...

# %%
merged.groupby(by='committee_name_x').amount.sum().reset_index().sort_values('amount',ascending=False)
# Out:
#                                      committee_name_x       amount
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 6                         MOMS STRONG AGAINST PROP 64      6281.64

# %%
merged.groupby(by=['contributor_firstname','contributor_lastname']).amount.sum().reset_index().sort_values('amount',ascending=False).head(3)
# Out:
#     contributor_firstname            contributor_lastname     amount
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 482                  SEAN                          PARKER  1500000.0
# 281                 JULIE                         SCHAUER  1364000.0

# %%
z=merged.groupby(by=['contributor_firstname','contributor_lastname','committee_position' ]).amount.sum().reset_index().sort_values('amount',ascending=False)

# %%
z.head(10)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 405              NICHOLAS                        PRITZKER            SUPPORT
# 421                 PETER                           THIEL            SUPPORT
# 456                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 322              LAWRENCE                            HESS            SUPPORT
#
#         amount
# 483  7250000.0
# 482  1500000.0
# 281  1364000.0
# 108  1250000.0
# 194  1000000.0
# 405   900000.0
# ...

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 549 entries, 483 to 136
# Data columns (total 4 columns):
# contributor_firstname    549 non-null object
# contributor_lastname     549 non-null object
# committee_position       549 non-null object
# amount                   549 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 21.4+ KB

# %%
top_supporters = merged.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(10)
top_supporters
# Out:
#     contributor_firstname            contributor_lastname     amount
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 482                  SEAN                          PARKER  1500000.0
# 281                 JULIE                         SCHAUER  1364000.0
# 108                DANIEL                           LEWIS  1250000.0
# 194                 HENRY                   VAN AMERINGEN  1000000.0
# 405              NICHOLAS                        PRITZKER   900000.0
# 421                 PETER                           THIEL   300000.0
# 456                 ROGER                         JENKINS    75000.0
# 23                 ANGELA                          HOWARD    65000.0
# 322              LAWRENCE                            HESS    30000.0

# %%
plt.figure()
ax1=plt.subplot(111)
xvals = range(len(top_supporters['amount']))
ax1.bar(xvals, top_supporters['amount'])
ax1.set_xticks(np.arange(10))
lastnames = []
for i in top_supporters['contributor_lastname']:
    lastnames.append(i)
lastnames[0] = 'PARKER ..'
lastnames[4] = 'V. AMERING.'
ax1.set_title('Top ten contributors on Prop 64')
ax1.set_ylabel('Dollars contributed')
ax1.set_xlabel('Contributor')
ax1.set_xticklabels(lastnames, rotation = 45)
plt.tight_layout()
#plt.savefig('toptenbar.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#top_supporters.to_csv("top_supporters.csv")

# %%
top_supporters['contributor_full_name']=top_supporters['contributor_firstname']+' '+top_supporters['contributor_lastname']

#text book version:
#def combine_names(row):
#    if row.contributor_full_name.startswith('SEAN PARKER'):
#        return 'SEAN PARKER'
#    return row.contributor_full_name

def combine_names(row):
    if row['contributor_full_name'].startswith('SEAN PARKER'):
        return 'SEAN PARKER'
    return row['contributor_full_name']

top_sup_cleaned = top_supporters.apply(combine_names,axis=1)
top_sup_cleaned
# Out:
# 483            SEAN PARKER
# 482            SEAN PARKER
# 281          JULIE SCHAUER
# 108           DANIEL LEWIS
# 194    HENRY VAN AMERINGEN
# 405      NICHOLAS PRITZKER
# 421            PETER THIEL
# 456          ROGER JENKINS
# 23           ANGELA HOWARD
# 322          LAWRENCE HESS
# dtype: object

# %%
top_supporters['clean_name']=top_sup_cleaned
top_supporters
# Out:
#     contributor_firstname            contributor_lastname     amount  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 482                  SEAN                          PARKER  1500000.0
# 281                 JULIE                         SCHAUER  1364000.0
# 108                DANIEL                           LEWIS  1250000.0
# 194                 HENRY                   VAN AMERINGEN  1000000.0
# 405              NICHOLAS                        PRITZKER   900000.0
# 421                 PETER                           THIEL   300000.0
# 456                 ROGER                         JENKINS    75000.0
# 23                 ANGELA                          HOWARD    65000.0
# 322              LAWRENCE                            HESS    30000.0
#
#                    contributor_full_name           clean_name
# 483  SEAN PARKER AND AFFILIATED ENTITIES          SEAN PARKER
# 482                          SEAN PARKER          SEAN PARKER
# ...

# %%
top_sup_cleaned_final = top_supporters.groupby('clean_name')['amount'].sum()
top_sup_cleaned_final = pd.DataFrame(top_sup_cleaned_final)
top_sup_cleaned_final = top_sup_cleaned_final.reset_index()
top_sup_cleaned_final = top_sup_cleaned_final.sort_values('amount', ascending=False)
top_sup_cleaned_final
# Out:
#             clean_name     amount
# 8          SEAN PARKER  8750000.0
# 3        JULIE SCHAUER  1364000.0
# 1         DANIEL LEWIS  1250000.0
# 2  HENRY VAN AMERINGEN  1000000.0
# 5    NICHOLAS PRITZKER   900000.0
# 6          PETER THIEL   300000.0
# 7        ROGER JENKINS    75000.0
# 0        ANGELA HOWARD    65000.0
# 4        LAWRENCE HESS    30000.0

# %%
plt.figure()
top_sup_cleaned_final_rev = top_sup_cleaned_final.sort_values('amount', ascending = True)

ax1 = plt.subplot(111)
xvals = range(len(top_sup_cleaned_final_rev))

ax1.barh(xvals,top_sup_cleaned_final_rev['amount'],color = 'gray', alpha = 0.65)
ax1.set_yticks(np.arange(10))
lastnames = []
for i in top_sup_cleaned_final_rev['clean_name']:
    lastnames.append(i)
ax1.set_title('Top ten contributors on Prop 64')
ax1.set_xlabel('Dollars contributed')
ax1.set_ylabel('Contributor')
ax1.set_yticklabels(lastnames, rotation = 45)
plt.tight_layout()
#plt.savefig('toptenbar.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## End of Data

# %% [markdown]
# # End

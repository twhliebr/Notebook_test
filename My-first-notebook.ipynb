# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
print re
print np
print pd
# Out:
# <module 're' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\re.pyc'>
# <module 'numpy' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\site-packages\numpy\__init__.pyc'>
# <module 'pandas' from 'c:\cygwin64\home\thomas\code\first-python-notebook\lib\site-packages\pandas\__init__.pyc'>

# %%
mylist=[2,4,6,8,10]
mylist
# Out:
# [2, 4, 6, 8, 10]

# %%
plt.figure()
ax1=plt.subplot(111)
ax1.plot(mylist, '--o', c='r', label='testdata')
ax1.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
my_series = pd.Series(mylist)
my_series
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
print my_series.mean()
print my_series.sum()
print my_series.std()
print my_series.describe()
print my_series.head(2)
# Out:
# 6.0
# 30
# 3.16227766017
# count     5.000000
# mean      6.000000
# std       3.162278
# min       2.000000
# 25%       4.000000
# 50%       6.000000
# 75%       8.000000
# max      10.000000
# dtype: float64
# 0    2
# 1    4
# dtype: int64
